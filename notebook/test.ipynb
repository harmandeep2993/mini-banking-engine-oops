# %%
from models.customer import Customer
from models.account import Account
from datetime import date

# %%
cust1 = Customer("John", "Doe", date(1995, 5, 10), "Berlin")

# %%
cust1

# %%
cust1 = Customer("John", "Joe", date(1993, 5, 10), "Berlin")

# %%
cust1

# %%
print(Customer.customer_registry)
# Out:
# {('John', 'Joe', datetime.date(1993, 5, 10)), ('John', 'Doe', datetime.date(1995, 5, 10))}

# %%
print(Customer.customers_id)
# Out:
# [70001, 70002]

# %%
cust1.get_accounts()
# Out:
# []

# %%
cust2.
